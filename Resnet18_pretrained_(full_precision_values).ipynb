# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install fvcore
# Out:
# Collecting fvcore
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fvcore) (1.25.2)
# Collecting yacs>=0.1.6 (from fvcore)
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from fvcore) (6.0.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from fvcore) (4.66.2)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from fvcore) (2.4.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from fvcore) (9.4.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from fvcore) (0.9.0)
# Collecting iopath>=0.1.7 (from fvcore)
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from iopath>=0.1.7->fvcore) (4.11.0)
# Collecting portalocker (from iopath>=0.1.7->fvcore)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Building wheels for collected packages: fvcore, iopath
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61400 sha256=df0d8b69cd59911590a155b315fdd6f9f97230027c949e792000c259448afcd9
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31532 sha256=347079827a83f0c8e4cc1599f2747dc280a245d597e43807a81ee19df5e27001
#   Stored in directory: /root/.cache/pip/wheels/9a/a3/b6/ac0fcd1b4ed5cfeb3db92e6a0e476cfd48ed0df92b91080c1d
# Successfully built fvcore iopath
# Installing collected packages: yacs, portalocker, iopath, fvcore
# Successfully installed fvcore-0.1.5.post20221221 iopath-0.1.10 portalocker-2.8.2 yacs-0.1.8

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import pandas as pd
import os
import matplotlib.pyplot as plt
from torchsummary import summary
import time
from torchvision import models, transforms
from fvcore.nn import FlopCountAnalysis, parameter_count_table

class CustomDataset(Dataset):
    def __init__(self, csv_file, root_dir, transform=None):
        self.data_frame = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform
        self.label_map = {label: index for index, label in enumerate(sorted(set(self.data_frame.iloc[:, 1])))}

    def __len__(self):
        return len(self.data_frame)

    def __getitem__(self, idx):
        img_name = os.path.join(self.root_dir, self.data_frame.iloc[idx, 0])
        image = Image.open(img_name).convert('RGB')
        label_str = self.data_frame.iloc[idx, 1]
        label = self.label_map[label_str]

        if self.transform:
            image = self.transform(image)

        return image, label

# Define transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Initialize dataset and data loader
train_dataset = CustomDataset(
    csv_file='/content/drive/MyDrive/Colab Notebooks/labels.csv',
    root_dir='/content/drive/MyDrive/jpg',
    transform=transform
)

train_size = int(0.8 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# Initialize and modify the model
model = models.resnet18(pretrained=True)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 17)

# Training setup
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Print model summary for MACCs
summary(model, input_size=(3, 224, 224))

start_event = torch.cuda.Event(enable_timing=True)
end_event = torch.cuda.Event(enable_timing=True)
start_event.record()

train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

# Training loop
for epoch in range(100):
    model.train()
    running_loss, train_correct, train_total = 0.0, 0, 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_accuracy = train_correct / train_total
    train_losses.append(train_loss)
    train_accuracies.append(train_accuracy)

    # Validation phase
    model.eval()
    val_running_loss, val_correct, val_total = 0.0, 0, 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            val_loss = criterion(outputs, labels)
            val_running_loss += val_loss.item()
            _, predicted = torch.max(outputs.data, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_loss = val_running_loss / len(val_loader)
    val_accuracy = val_correct / val_total
    val_losses.append(val_loss)
    val_accuracies.append(val_accuracy)

    print(f'Epoch {epoch+1}: Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.4f}')
end_event.record()
torch.cuda.synchronize()
elapsed_time_ms = start_event.elapsed_time(end_event)
print(f'Total training time: {elapsed_time_ms / 1000:.2f} seconds')

# Plotting
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#        BasicBlock-11           [-1, 64, 56, 56]               0
#            Conv2d-12           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-13           [-1, 64, 56, 56]             128
#              ReLU-14           [-1, 64, 56, 56]               0
#            Conv2d-15           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-16           [-1, 64, 56, 56]             128
#              ReLU-17           [-1, 64, 56, 56]               0
#        BasicBlock-18           [-1, 64, 56, 56]               0
#            Conv2d-19          [-1, 128, 28, 28]          73,728
#       BatchNorm2d-20          [-1, 128, 28, 28]             256
#              ReLU-21          [-1, 128, 28, 28]               0
#            Conv2d-22          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-23          [-1, 128, 28, 28]             256
#            Conv2d-24          [-1, 128, 28, 28]           8,192
#       BatchNorm2d-25          [-1, 128, 28, 28]             256
#              ReLU-26          [-1, 128, 28, 28]               0
#        BasicBlock-27          [-1, 128, 28, 28]               0
#            Conv2d-28          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-29          [-1, 128, 28, 28]             256
#              ReLU-30          [-1, 128, 28, 28]               0
#            Conv2d-31          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-32          [-1, 128, 28, 28]             256
#              ReLU-33          [-1, 128, 28, 28]               0
#        BasicBlock-34          [-1, 128, 28, 28]               0
#            Conv2d-35          [-1, 256, 14, 14]         294,912
#       BatchNorm2d-36          [-1, 256, 14, 14]             512
#              ReLU-37          [-1, 256, 14, 14]               0
#            Conv2d-38          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-39          [-1, 256, 14, 14]             512
#            Conv2d-40          [-1, 256, 14, 14]          32,768
#       BatchNorm2d-41          [-1, 256, 14, 14]             512
#              ReLU-42          [-1, 256, 14, 14]               0
#        BasicBlock-43          [-1, 256, 14, 14]               0
#            Conv2d-44          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-45          [-1, 256, 14, 14]             512
#              ReLU-46          [-1, 256, 14, 14]               0
#            Conv2d-47          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-48          [-1, 256, 14, 14]             512
#              ReLU-49          [-1, 256, 14, 14]               0
#        BasicBlock-50          [-1, 256, 14, 14]               0
#            Conv2d-51            [-1, 512, 7, 7]       1,179,648
#       BatchNorm2d-52            [-1, 512, 7, 7]           1,024
#              ReLU-53            [-1, 512, 7, 7]               0
#            Conv2d-54            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-55            [-1, 512, 7, 7]           1,024
#            Conv2d-56            [-1, 512, 7, 7]         131,072
#       BatchNorm2d-57            [-1, 512, 7, 7]           1,024
#              ReLU-58            [-1, 512, 7, 7]               0
#        BasicBlock-59            [-1, 512, 7, 7]               0
#            Conv2d-60            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-61            [-1, 512, 7, 7]           1,024
#              ReLU-62            [-1, 512, 7, 7]               0
#            Conv2d-63            [-1, 512, 7, 7]       2,359,296
#       BatchNorm2d-64            [-1, 512, 7, 7]           1,024
#              ReLU-65            [-1, 512, 7, 7]               0
#        BasicBlock-66            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                   [-1, 17]           8,721
# ================================================================
# Total params: 11,185,233
# Trainable params: 11,185,233
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 62.79
# Params size (MB): 42.67
# Estimated Total Size (MB): 106.03
# ----------------------------------------------------------------
# Epoch 1: Train Loss: 0.8529, Train Acc: 0.7400, Val Loss: 2.5818, Val Acc: 0.5055
# Epoch 2: Train Loss: 0.3080, Train Acc: 0.9173, Val Loss: 1.1036, Val Acc: 0.7673
# Epoch 3: Train Loss: 0.1871, Train Acc: 0.9427, Val Loss: 0.6676, Val Acc: 0.8109
# Epoch 4: Train Loss: 0.1273, Train Acc: 0.9609, Val Loss: 0.4511, Val Acc: 0.8982
# Epoch 5: Train Loss: 0.1121, Train Acc: 0.9645, Val Loss: 0.3282, Val Acc: 0.8982
# Epoch 6: Train Loss: 0.1547, Train Acc: 0.9564, Val Loss: 0.5664, Val Acc: 0.8509
# Epoch 7: Train Loss: 0.1648, Train Acc: 0.9482, Val Loss: 0.7188, Val Acc: 0.7818
# Epoch 8: Train Loss: 0.1537, Train Acc: 0.9555, Val Loss: 0.4703, Val Acc: 0.8364
# Epoch 9: Train Loss: 0.1481, Train Acc: 0.9582, Val Loss: 0.3372, Val Acc: 0.8945
# Epoch 10: Train Loss: 0.0882, Train Acc: 0.9745, Val Loss: 0.5421, Val Acc: 0.8836
# Epoch 11: Train Loss: 0.0890, Train Acc: 0.9791, Val Loss: 0.2167, Val Acc: 0.9418
# Epoch 12: Train Loss: 0.0249, Train Acc: 0.9936, Val Loss: 0.1486, Val Acc: 0.9491
# Epoch 13: Train Loss: 0.0187, Train Acc: 0.9955, Val Loss: 0.1847, Val Acc: 0.9345
# Epoch 14: Train Loss: 0.0072, Train Acc: 0.9991, Val Loss: 0.1796, Val Acc: 0.9527
# Epoch 15: Train Loss: 0.0028, Train Acc: 1.0000, Val Loss: 0.1142, Val Acc: 0.9636
# Epoch 16: Train Loss: 0.0013, Train Acc: 1.0000, Val Loss: 0.1272, Val Acc: 0.9709
# Epoch 17: Train Loss: 0.0010, Train Acc: 1.0000, Val Loss: 0.1168, Val Acc: 0.9709
# Epoch 18: Train Loss: 0.0012, Train Acc: 1.0000, Val Loss: 0.1207, Val Acc: 0.9673
# Epoch 19: Train Loss: 0.0007, Train Acc: 1.0000, Val Loss: 0.1117, Val Acc: 0.9709
# Epoch 20: Train Loss: 0.0027, Train Acc: 1.0000, Val Loss: 0.1572, Val Acc: 0.9600
# Epoch 21: Train Loss: 0.0110, Train Acc: 0.9982, Val Loss: 0.1355, Val Acc: 0.9564
# Epoch 22: Train Loss: 0.0893, Train Acc: 0.9764, Val Loss: 0.7897, Val Acc: 0.7855
# Epoch 23: Train Loss: 0.1137, Train Acc: 0.9682, Val Loss: 1.3367, Val Acc: 0.7564
# Epoch 24: Train Loss: 0.0832, Train Acc: 0.9755, Val Loss: 0.6770, Val Acc: 0.8764
# Epoch 25: Train Loss: 0.1231, Train Acc: 0.9745, Val Loss: 0.7848, Val Acc: 0.8582
# Epoch 26: Train Loss: 0.2035, Train Acc: 0.9391, Val Loss: 0.8546, Val Acc: 0.7891
# Epoch 27: Train Loss: 0.0973, Train Acc: 0.9691, Val Loss: 0.5518, Val Acc: 0.8291
# Epoch 28: Train Loss: 0.0560, Train Acc: 0.9845, Val Loss: 0.6018, Val Acc: 0.8364
# Epoch 29: Train Loss: 0.0294, Train Acc: 0.9909, Val Loss: 0.3627, Val Acc: 0.8800
# Epoch 30: Train Loss: 0.0187, Train Acc: 0.9936, Val Loss: 0.2891, Val Acc: 0.9200
# Epoch 31: Train Loss: 0.0096, Train Acc: 0.9982, Val Loss: 0.4831, Val Acc: 0.8945
# Epoch 32: Train Loss: 0.0268, Train Acc: 0.9927, Val Loss: 0.2414, Val Acc: 0.9309
# Epoch 33: Train Loss: 0.0307, Train Acc: 0.9900, Val Loss: 0.3608, Val Acc: 0.9127
# Epoch 34: Train Loss: 0.0288, Train Acc: 0.9918, Val Loss: 0.4446, Val Acc: 0.8764
# Epoch 35: Train Loss: 0.0493, Train Acc: 0.9864, Val Loss: 0.2480, Val Acc: 0.9236
# Epoch 36: Train Loss: 0.0077, Train Acc: 0.9991, Val Loss: 0.2229, Val Acc: 0.9345
# Epoch 37: Train Loss: 0.0174, Train Acc: 0.9973, Val Loss: 0.2462, Val Acc: 0.9273
# Epoch 38: Train Loss: 0.0407, Train Acc: 0.9900, Val Loss: 0.4494, Val Acc: 0.8691
# Epoch 39: Train Loss: 0.0139, Train Acc: 0.9927, Val Loss: 0.2723, Val Acc: 0.9055
# Epoch 40: Train Loss: 0.0099, Train Acc: 0.9991, Val Loss: 0.2749, Val Acc: 0.9164
# Epoch 41: Train Loss: 0.0512, Train Acc: 0.9909, Val Loss: 0.7118, Val Acc: 0.8473
# Epoch 42: Train Loss: 0.0775, Train Acc: 0.9800, Val Loss: 0.4286, Val Acc: 0.8582
# Epoch 43: Train Loss: 0.1013, Train Acc: 0.9645, Val Loss: 1.4945, Val Acc: 0.7673
# Epoch 44: Train Loss: 0.0753, Train Acc: 0.9764, Val Loss: 0.4324, Val Acc: 0.8982
# Epoch 45: Train Loss: 0.0357, Train Acc: 0.9864, Val Loss: 0.8038, Val Acc: 0.8218
# Epoch 46: Train Loss: 0.0449, Train Acc: 0.9855, Val Loss: 0.3406, Val Acc: 0.8982
# Epoch 47: Train Loss: 0.0187, Train Acc: 0.9964, Val Loss: 0.2671, Val Acc: 0.9200
# Epoch 48: Train Loss: 0.0193, Train Acc: 0.9964, Val Loss: 0.3261, Val Acc: 0.9018
# Epoch 49: Train Loss: 0.0172, Train Acc: 0.9927, Val Loss: 1.0326, Val Acc: 0.8364
# Epoch 50: Train Loss: 0.0159, Train Acc: 0.9945, Val Loss: 0.2814, Val Acc: 0.9236
# Epoch 51: Train Loss: 0.0034, Train Acc: 0.9991, Val Loss: 0.2473, Val Acc: 0.9273
# Epoch 52: Train Loss: 0.0035, Train Acc: 0.9982, Val Loss: 0.2267, Val Acc: 0.9455
# Epoch 53: Train Loss: 0.0014, Train Acc: 1.0000, Val Loss: 0.2278, Val Acc: 0.9455
# Epoch 54: Train Loss: 0.0005, Train Acc: 1.0000, Val Loss: 0.2154, Val Acc: 0.9491
# Epoch 55: Train Loss: 0.0003, Train Acc: 1.0000, Val Loss: 0.2183, Val Acc: 0.9491
# Epoch 56: Train Loss: 0.0004, Train Acc: 1.0000, Val Loss: 0.2168, Val Acc: 0.9527
# Epoch 57: Train Loss: 0.0005, Train Acc: 1.0000, Val Loss: 0.2165, Val Acc: 0.9455
# Epoch 58: Train Loss: 0.0005, Train Acc: 1.0000, Val Loss: 0.2353, Val Acc: 0.9382
# Epoch 59: Train Loss: 0.0003, Train Acc: 1.0000, Val Loss: 0.2058, Val Acc: 0.9527
# Epoch 60: Train Loss: 0.0033, Train Acc: 0.9991, Val Loss: 0.1916, Val Acc: 0.9491
# Epoch 61: Train Loss: 0.0108, Train Acc: 0.9964, Val Loss: 0.4547, Val Acc: 0.8909
# Epoch 62: Train Loss: 0.0867, Train Acc: 0.9800, Val Loss: 0.6036, Val Acc: 0.8691
# Epoch 63: Train Loss: 0.0842, Train Acc: 0.9791, Val Loss: 0.7681, Val Acc: 0.8145
# Epoch 64: Train Loss: 0.1490, Train Acc: 0.9609, Val Loss: 0.7723, Val Acc: 0.8364
# Epoch 65: Train Loss: 0.0882, Train Acc: 0.9736, Val Loss: 0.5573, Val Acc: 0.8473
# Epoch 66: Train Loss: 0.0433, Train Acc: 0.9836, Val Loss: 0.6238, Val Acc: 0.8436
# Epoch 67: Train Loss: 0.0804, Train Acc: 0.9773, Val Loss: 0.6874, Val Acc: 0.8255
# Epoch 68: Train Loss: 0.0454, Train Acc: 0.9845, Val Loss: 0.4025, Val Acc: 0.8945
# Epoch 69: Train Loss: 0.0100, Train Acc: 0.9982, Val Loss: 0.4625, Val Acc: 0.8873
# Epoch 70: Train Loss: 0.0031, Train Acc: 0.9991, Val Loss: 0.4124, Val Acc: 0.8945
# Epoch 71: Train Loss: 0.0026, Train Acc: 0.9991, Val Loss: 0.3242, Val Acc: 0.9127
# Epoch 72: Train Loss: 0.0006, Train Acc: 1.0000, Val Loss: 0.3010, Val Acc: 0.9127
# Epoch 73: Train Loss: 0.0006, Train Acc: 1.0000, Val Loss: 0.2958, Val Acc: 0.9200
# Epoch 74: Train Loss: 0.0010, Train Acc: 1.0000, Val Loss: 0.3047, Val Acc: 0.9200
# Epoch 75: Train Loss: 0.0003, Train Acc: 1.0000, Val Loss: 0.2851, Val Acc: 0.9273
# Epoch 76: Train Loss: 0.0005, Train Acc: 1.0000, Val Loss: 0.2487, Val Acc: 0.9309
# Epoch 77: Train Loss: 0.0021, Train Acc: 0.9991, Val Loss: 0.2537, Val Acc: 0.9345
# Epoch 78: Train Loss: 0.0241, Train Acc: 0.9936, Val Loss: 0.9142, Val Acc: 0.8327
# Epoch 79: Train Loss: 0.0175, Train Acc: 0.9955, Val Loss: 0.6064, Val Acc: 0.8582
# Epoch 80: Train Loss: 0.0324, Train Acc: 0.9900, Val Loss: 0.4343, Val Acc: 0.8727
# Epoch 81: Train Loss: 0.1197, Train Acc: 0.9727, Val Loss: 1.1929, Val Acc: 0.7673
# Epoch 82: Train Loss: 0.0788, Train Acc: 0.9782, Val Loss: 0.8653, Val Acc: 0.8545
# Epoch 83: Train Loss: 0.0492, Train Acc: 0.9873, Val Loss: 0.4259, Val Acc: 0.8909
# Epoch 84: Train Loss: 0.0084, Train Acc: 0.9964, Val Loss: 0.2717, Val Acc: 0.9418
# Epoch 85: Train Loss: 0.0055, Train Acc: 0.9991, Val Loss: 0.3168, Val Acc: 0.9200
# Epoch 86: Train Loss: 0.0120, Train Acc: 0.9964, Val Loss: 0.6078, Val Acc: 0.8800
# Epoch 87: Train Loss: 0.0389, Train Acc: 0.9918, Val Loss: 0.6133, Val Acc: 0.8727
# Epoch 88: Train Loss: 0.0400, Train Acc: 0.9855, Val Loss: 1.0115, Val Acc: 0.7927
# Epoch 89: Train Loss: 0.0824, Train Acc: 0.9782, Val Loss: 0.7371, Val Acc: 0.8545
# Epoch 90: Train Loss: 0.0663, Train Acc: 0.9809, Val Loss: 0.8778, Val Acc: 0.8000
# Epoch 91: Train Loss: 0.0400, Train Acc: 0.9918, Val Loss: 0.3147, Val Acc: 0.9127
# Epoch 92: Train Loss: 0.0041, Train Acc: 1.0000, Val Loss: 0.2897, Val Acc: 0.9200
# Epoch 93: Train Loss: 0.0016, Train Acc: 1.0000, Val Loss: 0.2511, Val Acc: 0.9236
# Epoch 94: Train Loss: 0.0024, Train Acc: 0.9991, Val Loss: 0.3021, Val Acc: 0.9236
# Epoch 95: Train Loss: 0.0005, Train Acc: 1.0000, Val Loss: 0.2557, Val Acc: 0.9309
# Epoch 96: Train Loss: 0.0007, Train Acc: 1.0000, Val Loss: 0.2448, Val Acc: 0.9236
# Epoch 97: Train Loss: 0.0005, Train Acc: 1.0000, Val Loss: 0.2433, Val Acc: 0.9236
# Epoch 98: Train Loss: 0.0003, Train Acc: 1.0000, Val Loss: 0.2482, Val Acc: 0.9273
# Epoch 99: Train Loss: 0.0001, Train Acc: 1.0000, Val Loss: 0.2430, Val Acc: 0.9309
# Epoch 100: Train Loss: 0.0002, Train Acc: 1.0000, Val Loss: 0.2714, Val Acc: 0.9309
# Total training time: 1364.11 seconds
